# %%
import numpy as np
import time
import scipy 
from scipy.linalg import khatri_rao
import itertools
from tqdm.notebook import tqdm

# %%
def dumb_als(tensor, rank, tol=1e-6, maxiter=100, verbose=0, seed=42):
    ndim = tensor.ndim
    dims = tensor.shape
    np.random.seed(seed)
    factors = [np.random.randn(dim, rank) for dim in dims]
    
    # tensor -> A
    # factors -> U^k
    # A_k = U^k @ (khatri_rao(U^i), i!=k).T
    # A_k.T = (khatri_rao(U^i), i!=k) @ U^k.T
    # B_k = (khatri_rao(U^i), i!=k)
    # A_k.T = B_k @ U^k.T
    # U^k.T = least_squares(B_k @ X - A_k.T)
    
    stop = False
    for it in range(maxiter):
        stop = 0
        for k in range(ndim):
            B_k = np.ones(rank).reshape(1, -1)
            for j in range(ndim):
                if j != k:
                    B_k = khatri_rao(B_k, factors[j])
            
            A_k = np.moveaxis(tensor, k, 0).reshape(dims[k], -1)
            prev = factors[k]
            if verbose == 2:
                print(B_k.shape)
                print(A_k.T.shape)
                print()
            factors[k] = np.linalg.lstsq(B_k, A_k.T, rcond=None)[0].T
            if np.linalg.norm(prev - factors[k]) < tol:
                stop += 1
                
        if verbose==1:
            print(f'iteration {it+1}/{maxiter}')
            B_1 = np.ones(rank).reshape(1, -1)
            for j in range(1, ndim):
                B_1 = khatri_rao(B_1, factors[j])
            A_1 = factors[0] @ B_1.T
            print(f'error = {np.linalg.norm(tensor.reshape(-1) - A_1.reshape(-1)):.5f}\n')
        if ndim - stop <= 1:
            break
    print(f'stopping iterations on {it+1}/{maxiter}')
    B_1 = np.ones(rank).reshape(1, -1)
    for j in range(1, ndim):
        B_1 = khatri_rao(B_1, factors[j])
    A_1 = factors[0] @ B_1.T
    error = np.linalg.norm(tensor.reshape(-1) - A_1.reshape(-1))
    print(f'final error = {error:.5f}\n')
    return factors, error

# %%
def norm_als(tensor, rank, tol=1e-6, maxiter=100, verbose=False, seed=42):
    ndim = tensor.ndim
    dims = tensor.shape
    np.random.seed(seed)
    factors = [np.random.randn(dim, rank) for dim in dims]
    
    # tensor -> A
    # factors -> U^k
    # A_k = U^k @ (khatri_rao(U^i), i!=k).T
    # A_k.T = (khatri_rao(U^i), i!=k) @ U^k.T
    # B_k = (khatri_rao(U^i), i!=k)
    # A_k.T = B_k @ U^k.T
    # U^k.T = least_squares(B_k @ X - A_k.T)
    
    # smart part:
    # X_k = B_k^* @ B_k = (khatri_rao(U^i), i!=k)^* @ (khatri_rao(U^i), i!=k) 
    # X_k = pointwise_product(U^i^*, U_i) for j != k
    # X<k = pointwise_product(U^i^*, U_i) for j < k
    # X>k = pointwise_product(U^i^*, U_i) for j > k
    # X_k = pointwise_product(X<k, X>k)
    # X<k+1 = pointwise_product(X<k, U^k+1^* @ U_k+1)
    
    # B_k * X = A_k.T - least squares
    # (B_k* @ B_k) * X = B_k* @ A_k.T
    # X = least_squares (X_k, B_k* @ A_k.T) 
    # wow! very cool!
    # very smart als
    
    stop = False
    X_less = [0] * (ndim + 1)
    X_more = [0] * (ndim + 1)    
    it = 1
    while it < maxiter:
        stop = 0
        X_less[0] = np.ones((rank, rank))
        X_more[-1] = np.ones((rank, rank))
        for j in reversed(list(range(ndim))):
            X_more[j] = np.multiply(X_more[j+1], factors[j].T @ factors[j])
        
        # left to right
        for k in range(ndim):
            X_k = np.multiply(X_less[k], X_more[k + 1])
            A_k = np.moveaxis(tensor, k, 0).reshape(dims[k], -1)
            prev = factors[k]
            
            B_k = np.ones(rank).reshape(1, -1)
            for j in range(ndim):
                if j != k:
                    B_k = khatri_rao(B_k, factors[j])
            
            if verbose == 2:
                print(k)
                print(X_k.shape)
                print(B_k.shape)
                print(A_k.T.shape)
                print()
            
            factors[k] = np.linalg.lstsq(X_k, B_k.T @ A_k.T, rcond=None)[0].T
            X_less[k + 1] = np.multiply(X_less[k], factors[k].T @ factors[k])

            if np.linalg.norm(prev - factors[k]) < tol:
                stop += 1
                
        if verbose==1:
            print(f'iteration {it}/{maxiter}')
            B_1 = np.ones(rank).reshape(1, -1)
            for j in range(1, ndim):
                B_1 = khatri_rao(B_1, factors[j])
            A_1 = factors[0] @ B_1.T
            print(f'error = {np.linalg.norm(tensor.reshape(-1) - A_1.reshape(-1)):.5f}\n')
        if ndim - stop <= 1:
            break
        it += 1
        
        stop = 0
        for j in range(1, ndim + 1):
            X_less[j] = np.multiply(X_less[j-1], factors[j-1].T @ factors[j-1])                                
        # right to left
        for k in reversed(list(range(ndim))):
            X_k = np.multiply(X_less[k], X_more[k + 1])
            A_k = np.moveaxis(tensor, k, 0).reshape(dims[k], -1)
            prev = factors[k]
            
            B_k = np.ones(rank).reshape(1, -1)
            for j in range(ndim):
                if j != k:
                    B_k = khatri_rao(B_k, factors[j])
            
            if verbose == 2:
                print(k)
                print(X_k.shape)
                print(B_k.shape)
                print(A_k.T.shape)
                print()
                
            factors[k] = np.linalg.lstsq(X_k, B_k.T @ A_k.T, rcond=None)[0].T
            X_more[k] = np.multiply(X_more[k + 1], factors[k].T @ factors[k])

            if np.linalg.norm(prev - factors[k]) < tol:
                stop += 1
                                
        if verbose==1:
            print(f'iteration {it}/{maxiter}')
            B_1 = np.ones(rank).reshape(1, -1)
            for j in range(1, ndim):
                B_1 = khatri_rao(B_1, factors[j])
            A_1 = factors[0] @ B_1.T
            print(f'error = {np.linalg.norm(tensor.reshape(-1) - A_1.reshape(-1)):.5f}\n')
        if ndim - stop <= 1:
            break
        it += 1
        
    print(f'stopping iterations on {it+1}/{maxiter}')
    B_1 = np.ones(rank).reshape(1, -1)
    for j in range(1, ndim):
        B_1 = khatri_rao(B_1, factors[j])
    A_1 = factors[0] @ B_1.T
    error = np.linalg.norm(tensor.reshape(-1) - A_1.reshape(-1))
    print(f'final error = {error:.5f}\n')
    return factors, error

# %%
sizes = np.array((10, 35, 20))
T = np.zeros(sizes)
for i in range(sizes[0]):
    for j in range(sizes[1]):
        for k in range(sizes[2]):
            T[i, j, k] = np.sin(i + j + k+20)
rank = 10
print('dumb_als')
factors, error = dumb_als(T, rank, verbose=1)
print(f'dumb_err={error}')

print('norm_als')
factors, error = norm_als(T, rank, verbose=1)
print(f'norm_err={error}')
# Out:
# dumb_als
# iteration 1/100
# error = 14.88554
#
# iteration 2/100
# error = 1.10638
#
# iteration 3/100
# error = 0.13741
#
# iteration 4/100
# error = 0.01712
#
# iteration 5/100
# error = 0.00213
#
# iteration 6/100
# error = 0.00027
#
# iteration 7/100
# error = 0.00003
#
# iteration 8/100
# error = 0.00000
#
# iteration 9/100
# error = 0.00000
#
# stopping iterations on 9/100
# final error = 0.00000
#
# norm_als
# iteration 1/100
# error = 14.88554
#
# iteration 2/100
# error = 3.59734
#
# iteration 3/100
# error = 0.81960
#
# iteration 4/100
# error = 0.20631
#
# iteration 5/100
# error = 0.05132
#
# iteration 6/100
# error = 0.01290
#
# iteration 7/100
# error = 0.00326
#
# iteration 8/100
# error = 0.00083
#
# iteration 9/100
# error = 0.00021
#
# iteration 10/100
# error = 0.00005
#
# stopping iterations on 11/100
# final error = 0.00005

# %%
sizes = np.array((10, 35, 20, 50, 40))
T = np.zeros(sizes)

st = time.time()
for I in itertools.product(*(range(i) for i in sizes)):
    T[I] = np.sin(sum(I))
print(f'filled tensor in {time.time() - st} seconds')
print(f'total elements in tensor = {np.prod(sizes)}')

print('\ndumb als')
st = time.time()
rank = 5
factors, dumb_error = dumb_als(T, rank, verbose=1)
dumb_als_time = time.time() - st

print('\nnorm als')
st = time.time()
rank = 5
factors, norm_error = norm_als(T, rank, verbose=1)
norm_als_time = time.time() - st
print(f'dumb_als_time = {dumb_als_time:.2f} seconds, error = {dumb_error:.5f}')
print(f'norm_als_time = {norm_als_time:.2f} seconds, error = {norm_error:.5f}')
# Out:
# filled tensor in 8.876933813095093 seconds
# total elements in tensor = 14000000
#
# dumb als
# iteration 1/100
# error = 2280.83467
#
# iteration 2/100
# error = 2046.71046
#
# iteration 3/100
# error = 1307.57345
#
# iteration 4/100
# error = 625.85631
#
# iteration 5/100
# error = 62.54004
#
# iteration 6/100
# error = 8.11693
#
# iteration 7/100
# error = 0.99112
#
# iteration 8/100
# error = 0.10669
#
# iteration 9/100
# error = 0.01519
#
# iteration 10/100
# error = 0.00153
#
# iteration 11/100
# error = 0.00011
#
# iteration 12/100
# error = 0.00002
#
# iteration 13/100
# error = 0.00000
#
# stopping iterations on 13/100
# final error = 0.00000
#
#
# norm als
# iteration 1/100
# error = 2280.83467
#
# iteration 2/100
# error = 1922.39162
#
# iteration 3/100
# error = 1627.97677
#
# iteration 4/100
# error = 1261.17731
#
# iteration 5/100
# error = 1034.03022
#
# iteration 6/100
# error = 931.01424
#
# iteration 7/100
# error = 726.50284
#
# iteration 8/100
# error = 520.40127
#
# iteration 9/100
# error = 43.14724
#
# iteration 10/100
# error = 8.13925
#
# iteration 11/100
# error = 1.61804
#
# iteration 12/100
# error = 0.34373
#
# iteration 13/100
# error = 0.07526
#
# iteration 14/100
# error = 0.01671
#
# iteration 15/100
# error = 0.00373
#
# iteration 16/100
# error = 0.00084
#
# iteration 17/100
# error = 0.00019
#
# iteration 18/100
# error = 0.00004
#
# iteration 19/100
# error = 0.00001
#
# iteration 20/100
# error = 0.00000
#
# stopping iterations on 21/100
# final error = 0.00000
#
# dumb_als_time = 14.23 seconds, error = 0.00000
# norm_als_time = 12.20 seconds, error = 0.00000

# %%
sizes = np.array((10, 35, 20, 50, 40))
T = np.zeros(sizes)

st = time.time()
for I in itertools.product(*(range(i) for i in sizes)):
    T[I] = np.sum(I)
print(f'filled tensor in {time.time() - st} seconds')
print(f'total elements in tensor = {np.prod(sizes)}')

print('\ndumb als')
st = time.time()
rank = 10
factors, dumb_error = dumb_als(T, rank, maxiter=20, verbose=1)
dumb_als_time = time.time() - st

print('\nnorm als')
st = time.time()
rank = 10
factors, norm_error = norm_als(T, rank, maxiter=20, verbose=1)
norm_als_time = time.time() - st
print(f'dumb_als_time = {dumb_als_time:.2f} seconds, error = {dumb_error:.5f}')
print(f'norm_als_time = {norm_als_time:.2f} seconds, error = {norm_error:.5f}')
# Out:
# filled tensor in 31.067357063293457 seconds
# total elements in tensor = 14000000
#
# dumb als
# iteration 1/20
# error = 968.80154
#
# iteration 2/20
# error = 118.55878
#
# iteration 3/20
# error = 34.23975
#
# iteration 4/20
# error = 32.98620
#
# iteration 5/20
# error = 32.35108
#
# iteration 6/20
# error = 31.91948
#
# iteration 7/20
# error = 31.57903
#
# iteration 8/20
# error = 31.27703
#
# iteration 9/20
# error = 30.98773
#
# iteration 10/20
# error = 30.69899
#
# iteration 11/20
# error = 30.40507
#
# iteration 12/20
# error = 30.10312
#
# iteration 13/20
# error = 29.79148
#
# iteration 14/20
# error = 29.46896
#
# iteration 15/20
# error = 29.13452
#
# iteration 16/20
# error = 28.78712
#
# iteration 17/20
# error = 28.42570
#
# iteration 18/20
# error = 28.04911
#
# iteration 19/20
# error = 27.65621
#
# iteration 20/20
# error = 27.24581
#
# stopping iterations on 20/20
# final error = 27.24581
#
#
# norm als
# iteration 1/20
# error = 968.80154
#
# iteration 2/20
# error = 74.64715
#
# iteration 3/20
# error = 60.58117
#
# iteration 4/20
# error = 52.67718
#
# iteration 5/20
# error = 47.55089
#
# iteration 6/20
# error = 44.14002
#
# iteration 7/20
# error = 41.47596
#
# iteration 8/20
# error = 39.37665
#
# iteration 9/20
# error = 37.55017
#
# iteration 10/20
# error = 35.99052
#
# iteration 11/20
# error = 34.57288
#
# iteration 12/20
# error = 33.32316
#
# iteration 13/20
# error = 32.16698
#
# iteration 14/20
# error = 31.12947
#
# iteration 15/20
# error = 30.16182
#
# iteration 16/20
# error = 29.28030
#
# iteration 17/20
# error = 28.45450
#
# iteration 18/20
# error = 27.68985
#
# iteration 19/20
# error = 26.97155
#
# iteration 20/20
# error = 26.29382
#
# stopping iterations on 22/20
# final error = 26.29382
#
# dumb_als_time = 42.10 seconds, error = 27.24581
# norm_als_time = 21.89 seconds, error = 26.29382

# %%
sizes = np.array((10, 35, 20, 50, 40))
T = np.zeros(sizes)

st = time.time()
for I in itertools.product(*(range(i) for i in sizes)):
    T[I] = 1 / (np.sum(I) + 1)
print(f'filled tensor in {time.time() - st} seconds')
print(f'total elements in tensor = {np.prod(sizes)}')

print('\ndumb als')
st = time.time()
rank = 5
factors, dumb_error = dumb_als(T, rank, maxiter=20, verbose=1)
dumb_als_time = time.time() - st

print('\nnorm als')
st = time.time()
rank = 5
factors, norm_error = norm_als(T, rank, maxiter=20, verbose=1)
norm_als_time = time.time() - st
print(f'dumb_als_time = {dumb_als_time:.2f} seconds, error = {dumb_error:.5f}')
print(f'norm_als_time = {norm_als_time:.2f} seconds, error = {norm_error:.5f}')
# Out:
# filled tensor in 31.71893286705017 seconds
# total elements in tensor = 14000000
#
# dumb als
# iteration 1/20
# error = 5.31220
#
# iteration 2/20
# error = 2.43273
#
# iteration 3/20
# error = 1.70007
#
# iteration 4/20
# error = 1.54805
#
# iteration 5/20
# error = 1.34100
#
# iteration 6/20
# error = 1.22884
#
# iteration 7/20
# error = 1.17647
#
# iteration 8/20
# error = 1.14575
#
# iteration 9/20
# error = 1.12366
#
# iteration 10/20
# error = 1.10633
#
# iteration 11/20
# error = 1.09200
#
# iteration 12/20
# error = 1.07961
#
# iteration 13/20
# error = 1.06847
#
# iteration 14/20
# error = 1.05813
#
# iteration 15/20
# error = 1.04831
#
# iteration 16/20
# error = 1.03880
#
# iteration 17/20
# error = 1.02945
#
# iteration 18/20
# error = 1.02017
#
# iteration 19/20
# error = 1.01087
#
# iteration 20/20
# error = 1.00146
#
# stopping iterations on 20/20
# final error = 1.00146
#
#
# norm als
# iteration 1/20
# error = 5.31220
#
# iteration 2/20
# error = 1.93002
#
# iteration 3/20
# error = 1.57271
#
# iteration 4/20
# error = 1.43170
#
# iteration 5/20
# error = 1.27071
#
# iteration 6/20
# error = 1.12180
#
# iteration 7/20
# error = 1.01453
#
# iteration 8/20
# error = 0.96795
#
# iteration 9/20
# error = 0.94210
#
# iteration 10/20
# error = 0.92832
#
# iteration 11/20
# error = 0.91734
#
# iteration 12/20
# error = 0.90692
#
# iteration 13/20
# error = 0.89747
#
# iteration 14/20
# error = 0.88823
#
# iteration 15/20
# error = 0.87968
#
# iteration 16/20
# error = 0.87129
#
# iteration 17/20
# error = 0.86343
#
# iteration 18/20
# error = 0.85570
#
# iteration 19/20
# error = 0.84839
#
# iteration 20/20
# error = 0.84120
#
# stopping iterations on 22/20
# final error = 0.84120
#
# dumb_als_time = 15.43 seconds, error = 1.00146
# norm_als_time = 8.16 seconds, error = 0.84120

# %%
sizes = np.array((15, 15, 15, 15, 15, 15))
T = np.zeros(sizes)

st = time.time()
for I in itertools.product(*(range(i) for i in sizes)):
    T[I] = np.sum(I)
print(f'filled tensor in {time.time() - st} seconds')
print(f'total elements in tensor = {np.prod(sizes)}')

print('\ndumb als')
st = time.time()
rank = 5
factors, dumb_error = dumb_als(T, rank, verbose=1)
dumb_als_time = time.time() - st

print('\nnorm als')
st = time.time()
rank = 5
factors, norm_error = norm_als(T, rank, verbose=1)
norm_als_time = time.time() - st
print(f'dumb_als_time = {dumb_als_time:.2f} seconds, error = {dumb_error:.5f}')
print(f'norm_als_time = {norm_als_time:.2f} seconds, error = {norm_error:.5f}')
# Out:
# filled tensor in 25.64196467399597 seconds
# total elements in tensor = 11390625
#
# dumb als
# iteration 1/100
# error = 4347.31785
#
# iteration 2/100
# error = 1832.43976
#
# iteration 3/100
# error = 927.12193
#
# iteration 4/100
# error = 680.38640
#
# iteration 5/100
# error = 617.80766
#
# iteration 6/100
# error = 583.63039
#
# iteration 7/100
# error = 549.64443
#
# iteration 8/100
# error = 517.10516
#
# iteration 9/100
# error = 486.38453
#
# iteration 10/100
# error = 457.11323
#
# iteration 11/100
# error = 428.69463
#
# iteration 12/100
# error = 400.42147
#
# iteration 13/100
# error = 371.46489
#
# iteration 14/100
# error = 340.80682
#
# iteration 15/100
# error = 307.16606
#
# iteration 16/100
# error = 269.05960
#
# iteration 17/100
# error = 225.54174
#
# iteration 18/100
# error = 178.93376
#
# iteration 19/100
# error = 138.31815
#
# iteration 20/100
# error = 112.55171
#
# iteration 21/100
# error = 99.21376
#
# iteration 22/100
# error = 91.98484
#
# iteration 23/100
# error = 87.30881
#
# iteration 24/100
# error = 83.80344
#
# iteration 25/100
# error = 80.85907
#
# iteration 26/100
# error = 78.16948
#
# iteration 27/100
# error = 75.56890
#
# iteration 28/100
# error = 72.95558
#
# iteration 29/100
# error = 70.24522
#
# iteration 30/100
# error = 67.27957
#
# iteration 31/100
# error = 57.84267
#
# iteration 32/100
# error = 30.63639
#
# iteration 33/100
# error = 15.17753
#
# iteration 34/100
# error = 14.31631
#
# iteration 35/100
# error = 13.85093
#
# iteration 36/100
# error = 13.51362
#
# iteration 37/100
# error = 13.27189
#
# iteration 38/100
# error = 13.09726
#
# iteration 39/100
# error = 12.96845
#
# iteration 40/100
# error = 12.87119
#
# iteration 41/100
# error = 12.79618
#
# iteration 42/100
# error = 12.73706
#
# iteration 43/100
# error = 12.68931
#
# iteration 44/100
# error = 12.64960
#
# iteration 45/100
# error = 12.61547
#
# iteration 46/100
# error = 12.58511
#
# iteration 47/100
# error = 12.55726
#
# iteration 48/100
# error = 12.53102
#
# iteration 49/100
# error = 12.50581
#
# iteration 50/100
# error = 12.48126
#
# iteration 51/100
# error = 12.45712
#
# iteration 52/100
# error = 12.43326
#
# iteration 53/100
# error = 12.40960
#
# iteration 54/100
# error = 12.38611
#
# iteration 55/100
# error = 12.36276
#
# iteration 56/100
# error = 12.33955
#
# iteration 57/100
# error = 12.31647
#
# iteration 58/100
# error = 12.29353
#
# iteration 59/100
# error = 12.27071
#
# iteration 60/100
# error = 12.24803
#
# iteration 61/100
# error = 12.22548
#
# iteration 62/100
# error = 12.20305
#
# iteration 63/100
# error = 12.18075
#
# iteration 64/100
# error = 12.15857
#
# iteration 65/100
# error = 12.13652
#
# iteration 66/100
# error = 12.11459
#
# iteration 67/100
# error = 12.09277
#
# iteration 68/100
# error = 12.07108
#
# iteration 69/100
# error = 12.04950
#
# iteration 70/100
# error = 12.02803
#
# iteration 71/100
# error = 12.00668
#
# iteration 72/100
# error = 11.98544
#
# iteration 73/100
# error = 11.96431
#
# iteration 74/100
# error = 11.94329
#
# iteration 75/100
# error = 11.92238
#
# iteration 76/100
# error = 11.90158
#
# iteration 77/100
# error = 11.88088
#
# iteration 78/100
# error = 11.86029
#
# iteration 79/100
# error = 11.83980
#
# iteration 80/100
# error = 11.81941
#
# iteration 81/100
# error = 11.79913
#
# iteration 82/100
# error = 11.77895
#
# iteration 83/100
# error = 11.75887
#
# iteration 84/100
# error = 11.73889
#
# iteration 85/100
# error = 11.71901
#
# iteration 86/100
# error = 11.69923
#
# iteration 87/100
# error = 11.67954
#
# iteration 88/100
# error = 11.65995
#
# iteration 89/100
# error = 11.64045
#
# iteration 90/100
# error = 11.62105
#
# iteration 91/100
# error = 11.60174
#
# iteration 92/100
# error = 11.58253
#
# iteration 93/100
# error = 11.56340
#
# iteration 94/100
# error = 11.54437
#
# iteration 95/100
# error = 11.52543
#
# iteration 96/100
# error = 11.50657
#
# iteration 97/100
# error = 11.48781
#
# iteration 98/100
# error = 11.46913
#
# iteration 99/100
# error = 11.45054
#
# iteration 100/100
# error = 11.43203
#
# stopping iterations on 100/100
# final error = 11.43203
#
#
# norm als
# iteration 1/100
# error = 4347.31785
#
# iteration 2/100
# error = 1938.94232
#
# iteration 3/100
# error = 1204.09010
#
# iteration 4/100
# error = 925.74928
#
# iteration 5/100
# error = 818.23689
#
# iteration 6/100
# error = 778.11573
#
# iteration 7/100
# error = 740.72003
#
# iteration 8/100
# error = 704.40306
#
# iteration 9/100
# error = 669.80351
#
# iteration 10/100
# error = 634.86160
#
# iteration 11/100
# error = 601.69135
#
# iteration 12/100
# error = 567.61528
#
# iteration 13/100
# error = 535.94250
#
# iteration 14/100
# error = 504.06787
#
# iteration 15/100
# error = 475.60052
#
# iteration 16/100
# error = 448.65066
#
# iteration 17/100
# error = 425.67553
#
# iteration 18/100
# error = 405.42279
#
# iteration 19/100
# error = 388.65793
#
# iteration 20/100
# error = 374.51684
#
# iteration 21/100
# error = 362.80344
#
# iteration 22/100
# error = 352.99717
#
# iteration 23/100
# error = 344.66963
#
# iteration 24/100
# error = 337.57481
#
# iteration 25/100
# error = 331.33073
#
# iteration 26/100
# error = 325.85171
#
# iteration 27/100
# error = 320.85855
#
# iteration 28/100
# error = 316.32733
#
# iteration 29/100
# error = 312.08547
#
# iteration 30/100
# error = 308.09841
#
# iteration 31/100
# error = 304.30416
#
# iteration 32/100
# error = 300.60138
#
# iteration 33/100
# error = 297.05327
#
# iteration 34/100
# error = 293.44107
#
# iteration 35/100
# error = 289.98091
#
# iteration 36/100
# error = 286.27939
#
# iteration 37/100
# error = 282.75294
#
# iteration 38/100
# error = 278.74953
#
# iteration 39/100
# error = 274.97100
#
# iteration 40/100
# error = 270.35992
#
# iteration 41/100
# error = 266.06591
#
# iteration 42/100
# error = 260.35513
#
# iteration 43/100
# error = 255.14038
#
# iteration 44/100
# error = 247.53616
#
# iteration 45/100
# error = 240.80972
#
# iteration 46/100
# error = 230.28134
#
# iteration 47/100
# error = 221.49322
#
# iteration 48/100
# error = 207.84551
#
# iteration 49/100
# error = 197.61872
#
# iteration 50/100
# error = 184.34506
#
# iteration 51/100
# error = 175.97489
#
# iteration 52/100
# error = 168.62299
#
# iteration 53/100
# error = 164.53867
#
# iteration 54/100
# error = 161.68806
#
# iteration 55/100
# error = 159.81451
#
# iteration 56/100
# error = 158.31928
#
# iteration 57/100
# error = 157.04286
#
# iteration 58/100
# error = 155.86411
#
# iteration 59/100
# error = 154.74226
#
# iteration 60/100
# error = 153.65769
#
# iteration 61/100
# error = 152.58987
#
# iteration 62/100
# error = 151.55181
#
# iteration 63/100
# error = 150.50620
#
# iteration 64/100
# error = 149.50219
#
# iteration 65/100
# error = 148.46814
#
# iteration 66/100
# error = 147.49289
#
# iteration 67/100
# error = 146.46701
#
# iteration 68/100
# error = 145.51629
#
# iteration 69/100
# error = 144.49291
#
# iteration 70/100
# error = 143.56120
#
# iteration 71/100
# error = 142.52784
#
# iteration 72/100
# error = 141.60536
#
# iteration 73/100
# error = 140.53658
#
# iteration 74/100
# error = 139.60014
#
# iteration 75/100
# error = 138.43873
#
# iteration 76/100
# error = 137.40311
#
# iteration 77/100
# error = 135.99505
#
# iteration 78/100
# error = 133.97404
#
# iteration 79/100
# error = 132.09165
#
# iteration 80/100
# error = 127.55476
#
# iteration 81/100
# error = 121.15501
#
# iteration 82/100
# error = 117.85857
#
# iteration 83/100
# error = 115.07706
#
# iteration 84/100
# error = 113.63992
#
# iteration 85/100
# error = 111.42969
#
# iteration 86/100
# error = 110.14837
#
# iteration 87/100
# error = 107.84927
#
# iteration 88/100
# error = 106.42972
#
# iteration 89/100
# error = 103.58084
#
# iteration 90/100
# error = 101.53809
#
# iteration 91/100
# error = 97.21000
#
# iteration 92/100
# error = 87.89925
#
# iteration 93/100
# error = 83.52748
#
# iteration 94/100
# error = 77.19076
#
# iteration 95/100
# error = 42.93981
#
# iteration 96/100
# error = 23.89006
#
# iteration 97/100
# error = 21.28584
#
# iteration 98/100
# error = 20.01847
#
# iteration 99/100
# error = 19.23645
#
# iteration 100/100
# error = 18.58543
#
# stopping iterations on 102/100
# final error = 18.58543
#
# dumb_als_time = 69.29 seconds, error = 11.43203
# norm_als_time = 32.06 seconds, error = 18.58543

# %%
sizes = np.array((10, 10, 10, 10, 10, 10))
T = np.zeros(sizes)
tensor_t = []
dumb_e = []
dumb_t = []
norm_e = []
norm_t = []
N = 100

for i in tqdm(range(N)):
    st = time.time()
    for I in itertools.product(*(range(i) for i in sizes)):
        T[I] = np.sum(I)
    tensor_t.append(time.time() - st)

    st = time.time()
    rank = 5
    factors, dumb_error = dumb_als(T, rank, verbose=0, seed=i**3)
    dumb_e.append(dumb_error)
    dumb_t.append(time.time() - st)
    
    st = time.time()
    rank = 5
    factors, norm_error = norm_als(T, rank, verbose=0, seed=i**3)
    norm_e.append(norm_error)
    norm_t.append(time.time() - st)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# stopping iterations on 100/100
# final error = 2.23651
#
# stopping iterations on 102/100
# final error = 4.97805
#
# stopping iterations on 100/100
# final error = 2.10944
#
# stopping iterations on 102/100
# final error = 23.27816
#
# stopping iterations on 100/100
# final error = 1.67158
#
# stopping iterations on 102/100
# final error = 0.11373
#
# stopping iterations on 100/100
# final error = 24.78722
#
# stopping iterations on 102/100
# final error = 17.55162
#
# stopping iterations on 100/100
# final error = 2.64028
#
# stopping iterations on 102/100
# final error = 0.50024
#
# stopping iterations on 100/100
# final error = 4.36220
#
# stopping iterations on 102/100
# final error = 7.70669
#
# stopping iterations on 100/100
# final error = 27.39996
#
# stopping iterations on 102/100
# final error = 15.40020
#
# stopping iterations on 100/100
# final error = 2.07043
#
# stopping iterations on 102/100
# final error = 13.14782
#
# stopping iterations on 100/100
# final error = 26.83788
#
# stopping iterations on 102/100
# final error = 107.21645
#
# stopping iterations on 100/100
# final error = 15.33378
#
# stopping iterations on 102/100
# final error = 76.37519
#
# stopping iterations on 100/100
# final error = 7.36220
#
# stopping iterations on 102/100
# final error = 136.50072
#
# stopping iterations on 100/100
# final error = 1.14524
#
# stopping iterations on 102/100
# final error = 3.48709
#
# stopping iterations on 100/100
# final error = 6.14713
#
# stopping iterations on 102/100
# final error = 25.94694
#
# stopping iterations on 100/100
# final error = 0.10858
#
# stopping iterations on 102/100
# final error = 43.14645
#
# stopping iterations on 100/100
# final error = 4.20379
#
# stopping iterations on 102/100
# final error = 3.51553
#
# stopping iterations on 100/100
# final error = 3.28520
#
# stopping iterations on 102/100
# final error = 2.59718
#
# stopping iterations on 100/100
# final error = 0.00326
#
# stopping iterations on 102/100
# final error = 13.62800
#
# stopping iterations on 100/100
# final error = 15.10456
#
# stopping iterations on 102/100
# final error = 50.03223
#
# stopping iterations on 100/100
# final error = 3.69935
#
# stopping iterations on 102/100
# final error = 4.44013
#
# stopping iterations on 100/100
# final error = 4.38860
#
# stopping iterations on 102/100
# final error = 4.57891
#
# stopping iterations on 100/100
# final error = 12.43324
#
# stopping iterations on 102/100
# final error = 30.98484
#
# stopping iterations on 100/100
# final error = 13.86931
#
# stopping iterations on 102/100
# final error = 60.31652
#
# stopping iterations on 100/100
# final error = 5.46536
#
# stopping iterations on 102/100
# final error = 52.01350
#
# stopping iterations on 100/100
# final error = 9.87173
#
# stopping iterations on 102/100
# final error = 16.54126
#
# stopping iterations on 100/100
# final error = 42.04343
#
# stopping iterations on 102/100
# final error = 9.12865
#
# stopping iterations on 100/100
# final error = 41.07382
#
# stopping iterations on 102/100
# final error = 0.00403
#
# stopping iterations on 100/100
# final error = 0.67593
#
# stopping iterations on 102/100
# final error = 2.52042
#
# stopping iterations on 100/100
# final error = 0.14377
#
# stopping iterations on 102/100
# final error = 1.72365
#
# stopping iterations on 100/100
# final error = 0.58523
#
# stopping iterations on 102/100
# final error = 0.21580
#
# stopping iterations on 100/100
# final error = 1.42892
#
# stopping iterations on 102/100
# final error = 3.45083
#
# stopping iterations on 100/100
# final error = 0.66524
#
# stopping iterations on 102/100
# final error = 0.04645
#
# stopping iterations on 100/100
# final error = 2.06027
#
# stopping iterations on 102/100
# final error = 0.59251
#
# stopping iterations on 100/100
# final error = 0.74924
#
# stopping iterations on 102/100
# final error = 0.58493
#
# stopping iterations on 100/100
# final error = 0.22902
#
# stopping iterations on 102/100
# final error = 0.37398
#
# stopping iterations on 100/100
# final error = 0.57058
#
# stopping iterations on 102/100
# final error = 0.12126
#
# stopping iterations on 100/100
# final error = 0.85290
#
# stopping iterations on 102/100
# final error = 61.29419
#
# stopping iterations on 100/100
# final error = 2.54855
#
# stopping iterations on 102/100
# final error = 13.31364
#
# stopping iterations on 100/100
# final error = 28.63348
#
# stopping iterations on 102/100
# final error = 13.72627
#
# stopping iterations on 100/100
# final error = 0.31739
#
# stopping iterations on 102/100
# final error = 0.40646
#
# stopping iterations on 100/100
# final error = 0.39615
#
# stopping iterations on 102/100
# final error = 7.67670
#
# stopping iterations on 100/100
# final error = 6.37151
#
# stopping iterations on 102/100
# final error = 4.97012
#
# stopping iterations on 100/100
# final error = 1.75572
#
# stopping iterations on 102/100
# final error = 1.16748
#
# stopping iterations on 100/100
# final error = 0.72088
#
# stopping iterations on 102/100
# final error = 0.46146
#
# stopping iterations on 100/100
# final error = 0.19554
#
# stopping iterations on 102/100
# final error = 1.74447
#
# stopping iterations on 100/100
# final error = 2.20736
#
# stopping iterations on 102/100
# final error = 8.19318
#
# stopping iterations on 100/100
# final error = 3.76446
#
# stopping iterations on 102/100
# final error = 58.39780
#
# stopping iterations on 100/100
# final error = 89.93621
#
# stopping iterations on 102/100
# final error = 42.11792
#
# stopping iterations on 100/100
# final error = 10.36484
#
# stopping iterations on 102/100
# final error = 51.68327
#
# stopping iterations on 100/100
# final error = 5.07522
#
# stopping iterations on 102/100
# final error = 0.00662
#
# stopping iterations on 100/100
# final error = 0.36697
#
# stopping iterations on 102/100
# final error = 41.90822
#
# stopping iterations on 100/100
# final error = 4.17606
#
# stopping iterations on 102/100
# final error = 7.90913
#
# stopping iterations on 100/100
# final error = 10.96866
#
# stopping iterations on 102/100
# final error = 2.29839
#
# stopping iterations on 100/100
# final error = 4.94876
#
# stopping iterations on 102/100
# final error = 15.47831
#
# stopping iterations on 100/100
# final error = 13.93121
#
# stopping iterations on 102/100
# final error = 3.31714
#
# stopping iterations on 100/100
# final error = 82.41014
#
# stopping iterations on 102/100
# final error = 101.51695
#
# stopping iterations on 100/100
# final error = 34.91526
#
# stopping iterations on 102/100
# final error = 0.36085
#
# stopping iterations on 100/100
# final error = 7.27195
#
# stopping iterations on 102/100
# final error = 12.01603
#
# stopping iterations on 100/100
# final error = 9.31368
#
# stopping iterations on 102/100
# final error = 7.19285
#
# stopping iterations on 100/100
# final error = 8.20976
#
# stopping iterations on 102/100
# final error = 1.50643
#
# stopping iterations on 100/100
# final error = 16.18534
#
# stopping iterations on 102/100
# final error = 25.75448
#
# stopping iterations on 100/100
# final error = 0.00240
#
# stopping iterations on 102/100
# final error = 8.60563
#
# stopping iterations on 100/100
# final error = 2.37462
#
# stopping iterations on 102/100
# final error = 18.18687
#
# stopping iterations on 100/100
# final error = 2.10512
#
# stopping iterations on 102/100
# final error = 8.17381
#
# stopping iterations on 100/100
# final error = 0.13770
#
# stopping iterations on 102/100
# final error = 1.52278
#
# stopping iterations on 100/100
# final error = 2.18786
#
# stopping iterations on 102/100
# final error = 2.89077
#
# stopping iterations on 100/100
# final error = 0.08498
#
# stopping iterations on 102/100
# final error = 11.21071
#
# stopping iterations on 100/100
# final error = 2.61051
#
# stopping iterations on 102/100
# final error = 5.47270
#
# stopping iterations on 100/100
# final error = 66.14535
#
# stopping iterations on 102/100
# final error = 10.31939
#
# stopping iterations on 100/100
# final error = 0.28275
#
# stopping iterations on 102/100
# final error = 2.86147
#
# stopping iterations on 100/100
# final error = 5.04808
#
# stopping iterations on 102/100
# final error = 5.46573
#
# stopping iterations on 100/100
# final error = 7.09042
#
# stopping iterations on 102/100
# final error = 4.78849
#
# stopping iterations on 100/100
# final error = 20.96549
#
# stopping iterations on 102/100
# final error = 1.22966
#
# stopping iterations on 100/100
# final error = 8.05908
#
# stopping iterations on 102/100
# final error = 0.02088
#
# stopping iterations on 100/100
# final error = 4.72095
#
# stopping iterations on 102/100
# final error = 1.68667
#
# stopping iterations on 100/100
# final error = 2.99622
#
# stopping iterations on 102/100
# final error = 19.08048
#
# stopping iterations on 100/100
# final error = 5.88035
#
# stopping iterations on 102/100
# final error = 5.01320
#
# stopping iterations on 100/100
# final error = 0.44671
#
# stopping iterations on 102/100
# final error = 3.62311
#
# stopping iterations on 100/100
# final error = 2.53865
#
# stopping iterations on 102/100
# final error = 7.04590
#
# stopping iterations on 100/100
# final error = 2.09269
#
# stopping iterations on 102/100
# final error = 1.86173
#
# stopping iterations on 100/100
# final error = 5.49598
#
# stopping iterations on 102/100
# final error = 0.01453
#
# stopping iterations on 100/100
# final error = 0.02169
#
# stopping iterations on 102/100
# final error = 4.88252
#
# stopping iterations on 100/100
# final error = 1.23564
#
# stopping iterations on 102/100
# final error = 2.57851
#
# stopping iterations on 100/100
# final error = 16.16864
#
# stopping iterations on 102/100
# final error = 2.53732
#
# stopping iterations on 100/100
# final error = 2.18829
#
# stopping iterations on 102/100
# final error = 1.11992
#
# stopping iterations on 100/100
# final error = 24.27970
#
# stopping iterations on 102/100
# final error = 41.24844
#
# stopping iterations on 100/100
# final error = 0.34404
#
# stopping iterations on 102/100
# final error = 0.10312
#
# stopping iterations on 100/100
# final error = 4.02370
#
# stopping iterations on 102/100
# final error = 2.23664
#
# stopping iterations on 100/100
# final error = 0.23716
#
# stopping iterations on 102/100
# final error = 1.15829
#
# stopping iterations on 100/100
# final error = 0.10868
#
# stopping iterations on 102/100
# final error = 0.49207
#
# stopping iterations on 100/100
# final error = 2.74039
#
# stopping iterations on 102/100
# final error = 3.15989
#
# stopping iterations on 100/100
# final error = 6.49927
#
# stopping iterations on 102/100
# final error = 15.37022
#
# stopping iterations on 100/100
# final error = 5.22154
#
# stopping iterations on 102/100
# final error = 2.33693
#
# stopping iterations on 100/100
# final error = 0.53923
#
# stopping iterations on 102/100
# final error = 1.90880
#
# stopping iterations on 100/100
# final error = 2.00465
#
# stopping iterations on 102/100
# final error = 71.16389
#
# stopping iterations on 100/100
# final error = 11.04152
#
# stopping iterations on 102/100
# final error = 16.11428
#
# stopping iterations on 100/100
# final error = 0.39402
#
# stopping iterations on 102/100
# final error = 7.55455
#
# stopping iterations on 100/100
# final error = 1.76160
#
# stopping iterations on 102/100
# final error = 68.46994
#
# stopping iterations on 100/100
# final error = 2.13502
#
# stopping iterations on 102/100
# final error = 1.92019
#
# stopping iterations on 100/100
# final error = 0.04030
#
# stopping iterations on 102/100
# final error = 0.16026
#
# stopping iterations on 100/100
# final error = 0.26206
#
# stopping iterations on 102/100
# final error = 6.75091
#
# statistics of 100 trials
# mean tensor creation time = 2.42
# mean dumb als time  = 6.36
# mean dumb als error = 8.55113
# mean norm als time  = 2.34
# mean norm als error = 15.87520

# %%
print(f'statistics of {N} trials')
print(f'mean tensor creation time = {np.mean(tensor_t):.2f}')
print(f'mean dumb als time  = {np.mean(dumb_t):.2f}')
print(f'mean dumb als error = {np.mean(dumb_e):.5f}')
print(f'mean norm als time  = {np.mean(norm_t):.2f}')
print(f'mean norm als error = {np.mean(norm_e):.5f}')
# Out:
# statistics of 100 trials
# mean tensor creation time = 2.42
# mean dumb als time  = 6.36
# mean dumb als error = 8.55113
# mean norm als time  = 2.34
# mean norm als error = 15.87520
